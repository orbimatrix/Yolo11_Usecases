# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.4/112.6 GB disk)

# %%
from ultralytics import YOLO

model = YOLO("yolo11m.pt")

results=model("/content/video.mp4",save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/460) /content/video.mp4: 384x640 12 persons, 108.7ms
# video 1/1 (frame 2/460) /content/video.mp4: 384x640 13 persons, 1 cell phone, 24.3ms
# video 1/1 (frame 3/460) /content/video.mp4: 384x640 13 persons, 1 cell phone, 35.2ms
# video 1/1 (frame 4/460) /content/video.mp4: 384x640 12 persons, 1 cell phone, 29.2ms
# video 1/1 (frame 5/460) /content/video.mp4: 384x640 12 persons, 1 cell phone, 24.3ms
# ...

# %% [markdown]
# # To Detect only Person Class, I have set the classes Paramtere to Zero.

# %%
results= model ("/content/video.mp4",classes=0,save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/460) /content/video.mp4: 384x640 12 persons, 11.2ms
# video 1/1 (frame 2/460) /content/video.mp4: 384x640 13 persons, 13.3ms
# video 1/1 (frame 3/460) /content/video.mp4: 384x640 13 persons, 11.2ms
# video 1/1 (frame 4/460) /content/video.mp4: 384x640 12 persons, 11.2ms
# video 1/1 (frame 5/460) /content/video.mp4: 384x640 12 persons, 11.4ms
# video 1/1 (frame 6/460) /content/video.mp4: 384x640 12 persons, 17.0ms
# ...

# %% [markdown]
# # Track

# %%
results=model.track(source="/content/video.mp4",persist=True,save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/460) /content/video.mp4: 384x640 12 persons, 11.1ms
# video 1/1 (frame 2/460) /content/video.mp4: 384x640 12 persons, 11.4ms
# video 1/1 (frame 3/460) /content/video.mp4: 384x640 13 persons, 11.6ms
# video 1/1 (frame 4/460) /content/video.mp4: 384x640 12 persons, 11.3ms
# video 1/1 (frame 5/460) /content/video.mp4: 384x640 12 persons, 11.4ms
# video 1/1 (frame 6/460) /content/video.mp4: 384x640 12 persons, 11.5ms
# ...

# %%
results=model.track("/content/video.mp4",persist=True,show=True,classes=0, tracker="bytetrack.yaml")
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs

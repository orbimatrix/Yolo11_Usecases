# %% [markdown]
# <a href="https://colab.research.google.com/github/orbimatrix/Yolo11_Usecases/blob/main/Yolo11_Usecase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model=YOLO("yolo11n.pt")

# %%
results=model("test.jpg")
results[0].show()

# %%
results=model("test2.jpg")
results[0].show()

# %%
results=model("football.jpg")
results[0].show()
# Out:
# image 1/1 /content/football.jpg: 384x640 6 persons, 2 sports balls, 84.8ms
# Speed: 2.8ms preprocess, 84.8ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=640x359>

# %% [markdown]
# # Object Detection with YOLO
#
# This notebook demonstrates how to perform object detection using the YOLO (You Only Look Once) model with the Ultralytics library.
#
# ## Setup
#
# The first cell installs the `ultralytics` library.

# %%
results=model("cars.mp4",save=True)
results[0].show()
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1319) /content/cars.mp4: 384x640 7 cars, 8.3ms
# video 1/1 (frame 2/1319) /content/cars.mp4: 384x640 7 cars, 10.4ms
# video 1/1 (frame 3/1319) /content/cars.mp4: 384x640 8 cars, 11.3ms
# video 1/1 (frame 4/1319) /content/cars.mp4: 384x640 8 cars, 11.4ms
# video 1/1 (frame 5/1319) /content/cars.mp4: 384x640 8 cars, 12.0ms
# video 1/1 (frame 6/1319) /content/cars.mp4: 384x640 8 cars, 10.4ms
# ...

# %% [markdown]
# Segmentation

# %%
from ultralytics import YOLO

model=YOLO("yolo11n-seg.pt")

results=model("test.jpg")
results[0].show()

# %% [markdown]
# Pose Estimation

# %%
from ultralytics import YOLO

model=YOLO("yolo11n-pose.pt")

results=model("test.jpg")
results[0].show()

# %% [markdown]
# Image Classification

# %%
from ultralytics import YOLO

model=YOLO("yolo11n-cls.pt")

results=model("test.jpg")
results[0].show()
# Out:
# image 1/1 /content/test.jpg: 224x224 miniskirt 0.36, fur_coat 0.15, maillot_(tights) 0.06, cowboy_boot 0.04, stole 0.04, 4.2ms
# Speed: 137.1ms preprocess, 4.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
